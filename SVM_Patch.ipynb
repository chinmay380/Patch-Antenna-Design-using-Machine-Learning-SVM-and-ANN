# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.metrics import f1_score

# %%
dataset = pd.read_csv('PATCH_DATASET.csv')

# %%
dataset.tail()
# Out:
#     epsilon    sh       w       l    s11  directivity   gain  efficency
# 94      3.0  1.90  45.794  37.399  4.080        6.627  5.042       69.4
# 95      3.0  1.95  45.994  37.599  4.113        6.635  5.139       70.9
# 96      3.0  1.20  46.194  37.799  3.553        6.566  4.969       69.2
# 97      3.0  2.00  46.194  37.799  4.147        6.642  5.232       72.3
# 98      3.0  1.00  43.994  35.599  3.429        6.511  3.762       53.1

# %%
dataset.describe()
# Out:
#          epsilon         sh          w          l        s11  directivity  \
# count  99.000000  99.000000  99.000000  99.000000  99.000000    99.000000
# mean    3.584040   1.502155  40.035309  33.663244  17.202667     6.467303
# std     0.903708   0.305631   3.985179   4.442494  15.327821     0.336685
# min     2.330000   1.000000  32.150000  27.680000   3.426000     6.086000
# 25%     3.000000   1.240000  37.125500  29.252000   3.813500     6.167000
# 50%     3.000000   1.500000  38.224000  34.399000   6.927000     6.521000
# 75%     4.600000   1.779500  43.894000  36.899000  31.211500     6.578500
# max     4.600000   2.000000  46.194000  43.000000  59.204000     7.905000
#
#             gain  efficency
# count  99.000000  99.000000
# mean    3.138556  49.122222
# std     1.724803  15.956590
# min     0.341000  26.600000
# 25%     1.558000  34.550000
# 50%     3.306000  47.900000
# 75%     4.702500  64.850000
# max     6.074000  79.100000

# %%
X = dataset.iloc[:, :4]  # Input features (Substrate height, Permittivity, Width, Length)
y = dataset.iloc[:, 4:]  # Output targets (S11, Directivity, Gain, Efficency)
feature_names = ['Epsilon', 'height of subs', 'Width', 'Length']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=84)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.to_numpy())
X_test_scaled = scaler.transform(X_test.to_numpy())

models = []
for i in range(y_train.shape[1]):
    model = SVR(kernel='rbf', C=66, gamma=0.1)  # Adjust the C and gamma values
    model.fit(X_train_scaled, y_train.iloc[:, i].to_numpy())
    models.append(model)

y_pred = []
for model in models:
    y_pred.append(model.predict(X_test_scaled))
y_pred = np.column_stack(y_pred)

# %%
new_inputs = [[3.0, 1.95, 45.994, 37.599]]  # Example inputs for prediction
new_inputs_scaled = scaler.transform(np.array(new_inputs))
predicted_output = []
for model in models:
    predicted_output.append(model.predict(new_inputs_scaled))
predicted_output = np.column_stack(predicted_output)
print("Predicted Output:",predicted_output)
# Out:
# Predicted Output: [[ 4.19404165  6.54071443  5.0458585  70.79042105]]

# %% [markdown]
#     ideal predicted values[4.113	6.635	5.139	70.9]

# %%
print(f"R2-score: {r2_score(y_test, y_pred)}")
print(f"MSE: {mean_squared_error(y_test, y_pred)}")
print(f"MAE: {mean_absolute_error(y_test, y_pred)}")
print(f"RMSE: {np.sqrt(mean_squared_error(y_test, y_pred))}")
# Out:
# R2-score: 0.9651026936313688
# MSE: 1.505530796568957
# MAE: 0.4421834275197863
# RMSE: 1.227000732097971
